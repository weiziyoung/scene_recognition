  5.3000e+01 7.9000e+01 9.9000e+01 1.2900e+02 1.5300e+02 2.1800e+02
  2.7500e+02 4.0100e+02]
 [2.0000e+00 6.0000e+00 1.0000e+01 4.3000e+01 5.7000e+01 1.1700e+02
  2.2700e+02 4.2800e+02 8.7900e+02 3.2460e+03 7.7460e+03 1.5286e+04
  2.9864e+04 3.8194e+04]]''')

# %%
adv_time = np.matrix('''[[2.060000e-04 7.620000e-04 1.412000e-03 3.822000e-03 5.622000e-03
  1.122600e-02 1.872400e-02 2.878600e-02 3.606600e-02 5.541300e-02
  9.577700e-02 1.246020e-01 1.348470e-01 2.123190e-01]
 [1.670000e-04 1.755830e+00 5.277220e+00 4.121091e+00 4.086845e+00
  1.867130e+00 1.773894e+00 1.906960e+00 1.654553e+00 3.412701e+00
  3.434002e+00 1.616470e-01 1.405088e+00 1.630231e+00]
 [1.500000e-04 1.141000e-03 3.728000e-03 5.330000e-03 8.843000e-03
  2.989300e-02 6.788000e-02 1.325000e-01 1.457620e-01 3.675500e-01
  6.176400e-01 1.423579e+00 2.614883e+00 3.720147e+00]
 [5.820000e-04 1.099000e-03 1.620000e-03 2.581000e-03 5.411000e-03
  3.831000e-03 7.347000e-03 1.291100e-02 1.340300e-02 1.691800e-02
  2.082400e-02 2.949200e-02 3.711300e-02 6.104500e-02]
 [2.430000e-04 8.330000e-04 9.250000e-04 3.736000e-03 5.742000e-03
  9.623000e-03 2.239500e-02 4.936800e-02 7.342000e-02 2.771430e-01
  6.582180e-01 1.327267e+00 3.010564e+00 4.057313e+00]]''')

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))
plt.plot(np.arange(1,15), expanded[0,:],label='BFS Performance')
plt.plot(np.arange(1,15), expanded[2,:], label='IDS Performance')
plt.xticks(np.arange(1,15))
plt.legend()
plt.xlabel('Depth of optimal solution(Complexity)')
plt.ylabel('Expanded Nodes')
plt.title('Difference in Expanded nodes between BFS and IDS with respect to Scalability')
# Out:
# Text(0.5, 1.0, 'Difference in Expanded nodes between BFS and IDS with respect to Scalability')

# %%
plt.figure(figsize=(10,5))
plt.plot(np.arange(1,15), time[0,:],label='BFS Performance')
plt.plot(np.arange(1,15), time[2,:], label='IDS Performance')
plt.xticks(np.arange(1,15))
plt.legend()
plt.xlabel('Depth of optimal solution(Complexity)')
plt.ylabel('Time consume(s)')
plt.title('Difference in consuming time between BFS and IDS with respect to Scalability')
# Out:
# Text(0.5, 1.0, 'Difference in consuming time between BFS and IDS with respect to Scalability')

# %%
plt.figure(figsize=(10,5))
plt.plot(np.arange(1,15), expanded[1,:],label='DFS Performance')
plt.plot(np.arange(1,15), expanded[3,:], label='A* Performance')
plt.xticks(np.arange(1,15))
plt.legend()
plt.xlabel('Depth of optimal solution(Complexity)')
plt.ylabel('Expanded nodes')
plt.title('Difference in expanded nodes between DFS and A* with respect to Scalability')
# Out:
# Text(0.5, 1.0, 'Difference in expanded nodes between DFS and A* with respect to Scalability')

# %%
plt.figure(figsize=(10,5))
plt.plot(np.arange(1,15), time[1,:],label='DFS Performance')
plt.plot(np.arange(1,15), time[3,:], label='A* Performance')
plt.xticks(np.arange(1,15))
plt.legend()
plt.xlabel('Depth of optimal solution(Complexity)')
plt.ylabel('Expanded nodes')
plt.title('Difference in expanded nodes between DFS and A* with respect to Scalability')
# Out:
# Text(0.5, 1.0, 'Difference in expanded nodes between DFS and A* with respect to Scalability')

# %%
adv_expanded = np.array(adv_expanded.reshape((5,14)))

# %%
adv_time = np.array(adv_time.reshape((5,14)))

# %%
plt.figure(figsize=(10,5))
plt.plot(np.arange(1,15), adv_expanded[0,:],label='adv BFS Performance')
plt.plot(np.arange(1,15), adv_expanded[1,:], label='adv DFS Performance')
plt.plot(np.arange(1,15), adv_expanded[2,:], label='adv IDS Performance')
plt.plot(np.arange(1,15), adv_expanded[3,:], label='adv a star Performance')
plt.plot(np.arange(1,15), adv_expanded[4,:], label='A star Performance')



plt.xticks(np.arange(1,15))
plt.legend()
plt.xlabel('Depth of optimal solution(Complexity)')
plt.ylabel('Number of Expanded Nodes')
plt.title('Difference in the number of expanded nodes between advanced methods with respect to Scalability')
# Out:
# Text(0.5, 1.0, 'Difference in the number of expanded nodes between advanced methods with respect to Scalability')

# %%
plt.figure(figsize=(10,5))
plt.plot(np.arange(1,15), adv_time[0,:],label='adv BFS Performance')
plt.plot(np.arange(1,15), adv_time[1,:], label='adv DFS Performance')
plt.plot(np.arange(1,15), adv_time[2,:], label='adv IDS Performance')
plt.plot(np.arange(1,15), adv_time[3,:], label='adv a star Performance')
plt.plot(np.arange(1,15), adv_time[4,:], label='A star Performance')


plt.xticks(np.arange(1,15))
plt.yticks(np.linspace(0, 5, 20))
plt.legend()
plt.xlabel('Depth of optimal solution(Complexity)')
plt.ylabel('Time consume(s)')
plt.title('Difference in consuming time between advanced methods with respect to Scalability')
# Out:
# Text(0.5, 1.0, 'Difference in consuming time between advanced methods with respect to Scalability')

# %%
agent_pos_node_benchmark = np.array([[  5.,   8.,  15.,  22.,  25.,  40.,  57.,  89., 104., 138., 204.,
        248., 323., 453.],
       [  5.,   8.,  14.,  21.,  24.,  31.,  53.,  79.,  99., 129., 153.,
        218., 275., 401.]])
agent_pos_time_benchmark = np.array([[0.002056, 0.002768, 0.006293, 0.009777, 0.011817, 0.019185,
        0.028852, 0.048549, 0.058044, 0.066998, 0.106559, 0.129884,
        0.168469, 0.238072],
       [0.001593, 0.002782, 0.005002, 0.00874 , 0.01063 , 0.013771,
        0.023734, 0.040316, 0.044541, 0.065926, 0.082627, 0.109429,
        0.14357 , 0.195392]])
plt.figure(figsize=(10,5))
plt.plot(np.arange(1,15), agent_pos_node_benchmark[0,:],label='Not calculate agent pos')
plt.plot(np.arange(1,15), agent_pos_node_benchmark[1,:], label='Calculate agent pos')
plt.legend()
plt.xticks(np.arange(1,15))
plt.xlabel('Depth of optimal solution(Complexity)')
plt.ylabel('Time consume(s)')
# Out:
# Text(0, 0.5, 'Time consume(s)')

# %%
adv_expanded[0,:]
# Out:
# matrix([[2.000e+00, 1.100e+01, 1.600e+01, 4.400e+01, 6.800e+01,
#          9.000e+01, 2.210e+02, 2.610e+02, 3.990e+02, 6.290e+02,
#          1.065e+03, 1.390e+03, 1.484e+03, 2.175e+03]])
